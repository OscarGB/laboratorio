# %%
F(x,a,b)=x^4 - 6 * x^2 + a*x + b

# %%
show([F])
# Out:
# [(x, a, b) |--> x^4 + a*x - 6*x^2 + b]

# %%
F(x,0,b)
# Out:
# x^4 - 6*x^2 + b

# %%
plot(F(x, 0, 2), (x, -2, 2))
# Out:
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Graphics object consisting of 1 graphics primitive

# %%
plot(F(x, 0, 8), (x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# plot muestra una gráfica. Sus argumentos son una función con sus parámetros, y un rango del parámetro que varía (x, -2, 2) indica que la variable x varía entre -2 y 2

# %%
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
G(x, a, b) = (x^2 - 3) ** 2 - 9 + b,

# %%
G(x, 0, b)
# Out:
# 2*x^2 + b - 15

# %%
show(G.expand())
# Out:
# (x, a, b) |--> x^4 - 6*x^2 + b

# %% [markdown]
# la funcion solve() recibe una función como primer argumento, y una variable a despejar como segundo. Devuelve una lista de soluciones al sistema.

# %%
solve(G(x, 0, b), x)
# Out:
# [x == -sqrt(sqrt(-b + 9) + 3), x == sqrt(sqrt(-b + 9) + 3), x == -sqrt(-sqrt(-b + 9) + 3), x == sqrt(-sqrt(-b + 9) + 3)]

# %%
G(x, 8, 0)
# Out:
# (x^2 - 3)^2 - 9

# %%
plot(G(x, 8, 0), (x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive
