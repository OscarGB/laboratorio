# %% [markdown]
# ## Ejercicio 1

# %%
def sumaN(n):
    suma = 0
    for i in srange(1, n+1):
        suma += i
    return suma

# %%
sumaN(4)
# Out:
# 10

# %%
L = [n for n in [1..1000] if factorial(n) % sumaN(n) != 0]

# %%
for n in L:
    print factor(n)
# Out:
# 2
# 2^2
# 2 * 3
# 2 * 5
# 2^2 * 3
# 2^4
# 2 * 3^2
# 2 * 11
# 2^2 * 7
# 2 * 3 * 5
# 2^2 * 3^2
# 2^3 * 5
# 2 * 3 * 7
# 2 * 23
# 2^2 * 13
# 2 * 29
# 2^2 * 3 * 5
# 2 * 3 * 11
# 2 * 5 * 7
# 2^3 * 3^2
# 2 * 3 * 13
# 2 * 41
# 2^3 * 11
# 2^5 * 3
# 2^2 * 5^2
# 2 * 3 * 17
# 2 * 53
# 2^2 * 3^3
# 2^4 * 7
# 2 * 3^2 * 7
# 2 * 5 * 13
# 2^3 * 17
# 2 * 3 * 23
# 2^2 * 37
# 2 * 3 * 5^2
# 2^2 * 3 * 13
# 2 * 3^4
# 2 * 83
# 2^2 * 43
# 2 * 89
# 2^2 * 3^2 * 5
# 2 * 5 * 19
# 2^6 * 3
# 2^2 * 7^2
# 2 * 3^2 * 11
# 2 * 3 * 5 * 7
# 2 * 3 * 37
# 2 * 113
# 2^2 * 3 * 19
# 2^3 * 29
# 2 * 7 * 17
# 2^4 * 3 * 5
# 2 * 5^3
# 2^8
# 2 * 131
# 2^2 * 67
# 2 * 3^3 * 5
# 2^2 * 3 * 23
# 2^3 * 5 * 7
# 2 * 3 * 47
# 2^2 * 73
# 2 * 3^2 * 17
# 2 * 5 * 31
# 2^3 * 3 * 13
# 2^2 * 79
# 2 * 3 * 5 * 11
# 2^4 * 3 * 7
# 2 * 173
# 2^2 * 3 * 29
# 2^5 * 11
# 2 * 179
# 2 * 3 * 61
# 2^2 * 3 * 31
# 2 * 3^3 * 7
# 2 * 191
# 2^2 * 97
# 2^2 * 3^2 * 11
# 2^4 * 5^2
# 2^3 * 3 * 17
# 2 * 11 * 19
# 2^2 * 3 * 5 * 7
# 2 * 5 * 43
# 2^4 * 3^3
# 2 * 3 * 73
# ...
