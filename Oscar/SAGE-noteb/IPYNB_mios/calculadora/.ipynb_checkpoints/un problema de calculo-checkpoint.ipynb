# %% [markdown]
# plot muestra la gráfica de p evaluado, entre los valores definidos en el segundo argumento.

# %%
p(x,a,b) = x^4 - 6 * x^2 + a*x + b

# %%
show(p)
# Out:
# (x, a, b) |--> x^4 + a*x - 6*x^2 + b

# %%
plot(p(x,0,0), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(p(x,0,2), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(p(x,0,-9), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(p(x,0,99), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(p(x,0,b), (x,-3,3), (b,-100,100))
# Out:
# Graphics3d Object

# %%
plot(p(x,8,0), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(p(x,0,b).factor())
# Out:
# x^4 - 6*x^2 + b

# %%
solve(p(x,0,b),x)
# Out:
# [x == -sqrt(sqrt(-b + 9) + 3), x == sqrt(sqrt(-b + 9) + 3), x == -sqrt(-sqrt(-b + 9) + 3), x == sqrt(-sqrt(-b + 9) + 3)]

# %%
g = p.derivate(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-99e3c9f0e6fa> in <module>()
# ----> 1 g = p.derivate(x)
#
# /usr/local/SageMath/src/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (/usr/local/SageMath/src/build/cythonized/sage/structure/element.c:4103)()
#     316             dummy_error_message.cls = type(self)
#     317             dummy_error_message.name = name
# --> 318             raise dummy_attribute_error
#     319         return getattr_from_other_class(self, P._abstract_element_class, name)
#     320
#
# AttributeError: 'sage.symbolic.expression.Expression' object has no attribute 'derivate'
