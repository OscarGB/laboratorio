# %%
var('t')
def dibuja_arco_circunferencia(radio, alpha):
    L1 = parametric_plot((radio*cos(t), radio*sin(t)), (t,0, pi))
    L2 = line2d([(sin(alpha), 0),(sin(alpha), 1)]) 
    L3 = line2d([(-cos(alpha), 0),(-cos(alpha), 1)])
    show(L1 + L2 + L3)

# %%
dibuja_arco_circunferencia(1, pi)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
f(x) = sqrt(1-x^2)

# %%
g(alpha) = integrate(f, x)

# %%
# Out:
# alpha |--> 1/2*sqrt(-x^2 + 1)*x + 1/2*arcsin(x)

# %%
def halla_area(alpha):
    if((-cos(alpha)) < sin(alpha)):
        a = integrate(f, x, -cos(alpha), sin(alpha))
        b = integrate(f, x, -1, -cos(alpha)) + integrate(f, x, sin(alpha), 1)
    else:
        a = integrate(f, x, sin(alpha), -cos(alpha))
        b = integrate(f, x, -1, sin(alpha)) + integrate(f, x, -cos(alpha), 1)
    return a/b

# %%
i = 0
m = 0
while(i < pi):
    aux = halla_area(i)
    if(aux > m):
        m = aux
    i += 0.01
print(m)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-192-c1bda55ca781> in <module>()
#       2 m = Integer(0)
#       3 while(i < pi):
# ----> 4     aux = halla_area(i)
#       5     if(aux > m):
#       6         m = aux
#
# <ipython-input-179-8a15716be1d8> in halla_area(alpha)
#       5     else:
#       6         a = integrate(f, x, sin(alpha), -cos(alpha))
# ----> 7         b = integrate(f, x, -Integer(1), sin(alpha)) + integrate(f, x, -cos(alpha), Integer(1))
#       8     return a/b
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/misc/functional.pyc in integral(x, *args, **kwds)
#     663     """
#     664     if hasattr(x, 'integral'):
# --> 665         return x.integral(*args, **kwds)
#     666     else:
#     667         from sage.symbolic.ring import SR
#
# /usr/local/SageMath/src/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.integral (/usr/local/SageMath/src/build/cythonized/sage/symbolic/expression.cpp:60545)()
#   11528                 else:   # all arguments are gone
#   11529                     R = ring.SR
# > 11530             return R(integral(f, v, a, b, **kwds))
#   11531         return integral(self, *args, **kwds)
#   11532
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/symbolic/integration/integral.pyc in integrate(expression, v, a, b, algorithm, hold)
#     763         return indefinite_integral(expression, v, hold=hold)
#     764     else:
# --> 765         return definite_integral(expression, v, a, b, hold=hold)
#     766
#     767 integral = integrate
#
# /usr/local/SageMath/src/sage/symbolic/function.pyx in sage.symbolic.function.BuiltinFunction.__call__ (/usr/local/SageMath/src/build/cythonized/sage/symbolic/function.cpp:11034)()
#     970             res = self._evalf_try_(*args)
#     971             if res is None:
# --> 972                 res = super(BuiltinFunction, self).__call__(
#     973                         *args, coerce=coerce, hold=hold)
#     974
#
# /usr/local/SageMath/src/sage/symbolic/function.pyx in sage.symbolic.function.Function.__call__ (/usr/local/SageMath/src/build/cythonized/sage/symbolic/function.cpp:6785)()
#     481             for i from 0 <= i < len(args):
#     482                 vec.push_back((<Expression>args[i])._gobj)
# --> 483             res = g_function_evalv(self._serial, vec, hold)
#     484         elif self._nargs == 1:
#     485             res = g_function_eval1(self._serial,
#
# /usr/local/SageMath/src/sage/symbolic/function.pyx in sage.symbolic.function.BuiltinFunction._evalf_or_eval_ (/usr/local/SageMath/src/build/cythonized/sage/symbolic/function.cpp:12281)()
#    1059         res = self._evalf_try_(*args)
#    1060         if res is None:
# -> 1061             return self._eval0_(*args)
#    1062         else:
#    1063             return res
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/symbolic/integration/integral.pyc in _eval_(self, f, x, a, b)
#     176         for integrator in self.integrators:
#     177             try:
# --> 178                 return integrator(*args)
#     179             except NotImplementedError:
#     180                 pass
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/symbolic/integration/external.pyc in maxima_integrator(expression, v, a, b)
#      22         result = maxima.sr_integral(expression,v)
#      23     else:
# ---> 24         result = maxima.sr_integral(expression, v, a, b)
#      25     return result._sage_()
#      26
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/interfaces/maxima_lib.py in sr_integral(self, *args)
#     797         """
#     798         try:
# --> 799             return max_to_sr(maxima_eval(([max_integrate],[sr_to_max(SR(a)) for a in args])))
#     800         except RuntimeError as error:
#     801             s = str(error)
#
# /usr/local/SageMath/src/sage/libs/ecl.pyx in sage.libs.ecl.EclObject.__call__ (/usr/local/SageMath/src/build/cythonized/sage/libs/ecl.c:7804)()
#     794         """
#     795         lispargs = EclObject(list(args))
# --> 796         return ecl_wrap(ecl_safe_apply(self.obj,(<EclObject>lispargs).obj))
#     797
#     798     def __richcmp__(left, right, int op):
#
# /usr/local/SageMath/src/sage/libs/ecl.pyx in sage.libs.ecl.ecl_safe_apply (/usr/local/SageMath/src/build/cythonized/sage/libs/ecl.c:5428)()
#     367     if ecl_nvalues > 1:
#     368         s = si_coerce_to_base_string(ecl_values(1))
# --> 369         raise RuntimeError("ECL says: "+ecl_base_string_pointer_safe(s))
#     370     else:
#     371         return ecl_values(0)
#
# RuntimeError: ECL says: Console interrupt.
