# %% [markdown]
# 1. Encontrar la condicion necesaria y suficiente sobre el entero n para que
# $1 + 2 + 3 + . . . + n$ divida exactamente a $n!$. Una vez encontrada hay que
# intentar demostrar la equivalencia.
# 2. Encontrar la condicion necesaria y suficiente para que existan infinitos
# multiplos de un entero n que se escriban unicamente con unos en base 10. Una vez encontrada hay que intentar demostrar la equivalencia. ¿Ocurrira algo similar si queremos que infinitos multiplos se escriban usando unicamente otro dıgito (2 ,3, etc.)?
# 3. La cifra dominante de un entero es la primera por la izquierda que no es nula. Encontrar los dıgitos que pueden ser la cifra dominante al mismo tiempo de 2n y 5n, con el mismo exponente n. Una vez encontrados, hay que intentar demostrar que esos dıgitos son los unicos posibles, pero, en este caso, no me han sido de ninguna ayuda las pruebas que he hecho con el ordenador.
# 4. Demuestra que para n > 1 el entero n
# 4 + 4 es siempre compuesto.

# %% [markdown]
# # Ejercicio 1

# %%
def suma(n):
    suma = 0
    for i in srange(1, n+1):
        suma += i
    return suma

# %%
L = [n for n in srange(1, 1000) if factorial(n)%((n*(n+1))/2)==0]

# %%
for n in L:
    print factor(n)
# Out:
# 1
# 3
# 5
# 7
# 2^3
# 3^2
# 11
# 13
# 2 * 7
# 3 * 5
# 17
# 19
# 2^2 * 5
# 3 * 7
# 23
# 2^3 * 3
# 5^2
# 2 * 13
# 3^3
# 29
# 31
# 2^5
# 3 * 11
# 2 * 17
# 5 * 7
# 37
# 2 * 19
# 3 * 13
# 41
# 43
# 2^2 * 11
# 3^2 * 5
# 47
# 2^4 * 3
# 7^2
# 2 * 5^2
# 3 * 17
# 53
# 2 * 3^3
# 5 * 11
# 2^3 * 7
# 3 * 19
# 59
# 61
# 2 * 31
# 3^2 * 7
# 2^6
# 5 * 13
# 67
# 2^2 * 17
# 3 * 23
# 71
# 73
# 2 * 37
# 3 * 5^2
# 2^2 * 19
# 7 * 11
# 79
# 2^4 * 5
# 3^4
# 83
# 2^2 * 3 * 7
# 5 * 17
# 2 * 43
# 3 * 29
# 89
# 2 * 3^2 * 5
# 7 * 13
# 2^2 * 23
# 3 * 31
# 2 * 47
# 5 * 19
# 97
# 2 * 7^2
# 3^2 * 11
# 101
# 103
# 2^3 * 13
# 3 * 5 * 7
# 107
# 109
# 2 * 5 * 11
# 3 * 37
# 113
# 2 * 3 * 19
# 5 * 23
# 2^2 * 29
# 3^2 * 13
# 2 * 59
# 7 * 17
# 2^3 * 3 * 5
# 11^2
# 2 * 61
# 3 * 41
# 2^2 * 31
# 5^3
# 127
# 2^7
# 3 * 43
# 131
# 2^2 * 3 * 11
# 7 * 19
# 2 * 67
# 3^3 * 5
# 137
# 139
# 2^2 * 5 * 7
# 3 * 47
# 2 * 71
# 11 * 13
# 2^4 * 3^2
# 5 * 29
# 2 * 73
# 3 * 7^2
# 149
# 151
# 2^3 * 19
# 3^2 * 17
# 2 * 7 * 11
# 5 * 31
# 157
# ...

# %% [markdown]
# Que sea primo
